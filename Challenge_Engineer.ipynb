# %% [markdown]
# #### Challenge Engineer

# %%
import json
import requests
import pandas as pd
from urllib import response
import requests

# %% [markdown]
# Conexion al enlace y exploración

# %%
url ='https://api.stackexchange.com/2.2/search?order=desc&sort=activity&intitle=perl&site=stackoverflow'
response = requests.get(url).json()
data=response["items"]
df=pd.json_normalize(data,max_level=1)
df.head()
# Out:
#                                    tags  is_answered  view_count  \
# 0            [perl, formatting, report]         True          92
# 1                         [regex, perl]         True          52
# 2                         [regex, perl]         True          40
# 3                                [perl]         True          44
# 4  [sorting, perl, hash, cmp, arrayref]         True          19
#
#    accepted_answer_id  answer_count  score  last_activity_date  creation_date  \
# 0          73173139.0             1      1          1660676235     1659089796
# 1                 NaN             2      1          1660675116     1660663813
# 2          73376850.0             2      2          1660674530     1660664991
# 3          73376046.0             1     -1          1660673970     1660660897
# 4                 NaN             1      0          1660672376     1660671059
#
#    last_edit_date  question_id  ...  \
# 0    1.659768e+09     73165106  ...
# ...

# %% [markdown]
# Obtener el número de respuestas contestadas y no contestadas

# %%
respondidas = "Total de preguntas respondidas: " + str( df[df["is_answered"]==True]["is_answered"].count())
no_respondidas = "Total de preguntas no respondidas: " + str( df[df["is_answered"]==False]["is_answered"].count())
print(respondidas)
print(no_respondidas)
# Out:
# Total de preguntas respondidas: 26
# Total de preguntas no respondidas: 4

# %% [markdown]
# Obtener la respuesta con menor número de vistas

# %%
df[df["view_count"]==df["view_count"].min()]
# Out:
#                                    tags  is_answered  view_count  \
# 4  [sorting, perl, hash, cmp, arrayref]         True          19
#
#    accepted_answer_id  answer_count  score  last_activity_date  creation_date  \
# 4                 NaN             1      0          1660672376     1660671059
#
#    last_edit_date  question_id  ...  \
# 4             NaN     73378028  ...
#
#                                                title owner.reputation  \
# 4  Perl: sort hash ref using multiple array ref v...              674
#
#   owner.user_id  owner.user_type  \
# 4       2035207       registered
#
#                                  owner.profile_image owner.display_name  \
# 4  https://www.gravatar.com/avatar/23407540c4b23e...                h q
#
#                                     owner.link owner.accept_rate  \
# 4  https://stackoverflow.com/users/2035207/h-q              71.0
#
#     closed_date               closed_reason
# 4  1.660677e+09  Not suitable for this site
#
# ...

# %% [markdown]
# Obtener la respuesta más vieja y más actual

# %%
df[df["creation_date"]==df["creation_date"].min()]
# Out:
#                       tags  is_answered  view_count  accepted_answer_id  \
# 27  [perl, cross-platform]         True       69346            334700.0
#
#     answer_count  score  last_activity_date  creation_date  last_edit_date  \
# 27            11     60          1660317247     1228237140    1.228354e+09
#
#     question_id  ...                                           title  \
# 27       334686  ...  How can I detect the operating system in Perl?
#
#    owner.reputation owner.user_id  owner.user_type  \
# 27            25631          6444       registered
#
#                                   owner.profile_image owner.display_name  \
# 27  https://www.gravatar.com/avatar/1510549f9353c9...               mxcl
#
#                                    owner.link owner.accept_rate closed_date  \
# 27  https://stackoverflow.com/users/6444/mxcl              78.0         NaN
#
#     closed_reason
# 27            NaN
#
# [1 rows x 22 columns]

# %%
df[df["creation_date"]==df["creation_date"].max()]
# Out:
#                                    tags  is_answered  view_count  \
# 4  [sorting, perl, hash, cmp, arrayref]         True          19
#
#    accepted_answer_id  answer_count  score  last_activity_date  creation_date  \
# 4                 NaN             1      0          1660672376     1660671059
#
#    last_edit_date  question_id  ...  \
# 4             NaN     73378028  ...
#
#                                                title owner.reputation  \
# 4  Perl: sort hash ref using multiple array ref v...              674
#
#   owner.user_id  owner.user_type  \
# 4       2035207       registered
#
#                                  owner.profile_image owner.display_name  \
# 4  https://www.gravatar.com/avatar/23407540c4b23e...                h q
#
#                                     owner.link owner.accept_rate  \
# 4  https://stackoverflow.com/users/2035207/h-q              71.0
#
#     closed_date               closed_reason
# 4  1.660677e+09  Not suitable for this site
#
# ...

# %% [markdown]
# Obtener la respuesta del owner que tenga una mayor reputación

# %%
df[df["owner.reputation"]==df["owner.reputation"].max()]
# Out:
#                       tags  is_answered  view_count  accepted_answer_id  \
# 27  [perl, cross-platform]         True       69346            334700.0
#
#     answer_count  score  last_activity_date  creation_date  last_edit_date  \
# 27            11     60          1660317247     1228237140    1.228354e+09
#
#     question_id  ...                                           title  \
# 27       334686  ...  How can I detect the operating system in Perl?
#
#    owner.reputation owner.user_id  owner.user_type  \
# 27            25631          6444       registered
#
#                                   owner.profile_image owner.display_name  \
# 27  https://www.gravatar.com/avatar/1510549f9353c9...               mxcl
#
#                                    owner.link owner.accept_rate closed_date  \
# 27  https://stackoverflow.com/users/6444/mxcl              78.0         NaN
#
#     closed_reason
# 27            NaN
#
# [1 rows x 22 columns]
